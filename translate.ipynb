# %%
#vertalen lijstje joran, welke landen wil pim
# English, Japanese, hindi, french, Arabic, portugese, spanish
# 
words = ['josh','adore',
 'horse',
 'sense',
 'occasionally',
 'cousin',
 'hater',
 'life',
 'station',
 'affair',
 'deep',
 'also',
 'us',
 'real',
 'animal',
 'future',
 'proud',
 'day',
 'lover',
 'guy',
 'dude',
 'bous',
 'lovely',
 'create',
 'dont',
 'drink',
 'better',
 'thanks',
 'someone',
 'mom',
 'boobs',
 'math',
 '100',
 'loan',
 'shark',
 'martial',
 'pains',
 'gains',
 'learner',
 'law',
 'language',
 'master',
 'culture',
 'rock',
 'green',
 'saddens',
 'think',
 'pretend',
 'trust',
 'dance',
 'blogging',
 'dior',
 'ad',
 'another',
 'thought',
 "that's",
 'around',
 'cannot',
 'name',
 'small',
 'enjoy',
 'hunt',
 'christian',
 'reading',
 'cigarettes',
 'energy',
 'member',
 'singer',
 'call',
 'agent','mommy','high','High','sexual','gay','death']

from googletrans import Translator
import pandas as pd
translator = Translator()
df = pd.DataFrame(words).rename(columns={0:'English'})
df['Spanish'] = df['English'].apply(translator.translate, src='es', dest='en').apply(getattr, args=('text',))
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2585/2399525981.py in <module>
#      76 translator = Translator()
#      77 df = pd.DataFrame(words).rename(columns={0:'English'})
# ---> 78 df['Spanish'] = df['English'].apply(translator.translate, src='es', dest='en').apply(getattr, args=('text',))
#      79 df
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/.local/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
 df.head()
# Out:
#               0
# 0          josh
# 1         adore
# 2         horse
# 3         sense
# 4  occasionally
